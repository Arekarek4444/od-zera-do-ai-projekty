# %%
def calculate_area (lenght, widtch):
    area = lenght * widtch
    return area
print(calculate_area (10, 20))
# Out:
# 200

# %%
def calculate_area (lenght, widtch):
    area = lenght * widtch
    return area
print(calculate_area (50, 20))
# Out:
# 1000

# %%
def calculate_area (lenght, widtch):
    area = lenght * widtch
    return area
print(calculate_area (3450, 238))
# Out:
# 821100

# %%
a = 5
b = 3

print(5 // 3)
# Out:
# 1

# %%
print(a // b)
# Out:
# 1

# %%
print(a == b)
# Out:
# False

# %%
print(a // b)
# Out:
# 1

# %%
print(a % b)
# Out:
# 2

# %%
print(b % a)
# Out:
# 3

# %%
print(b // a)
# Out:
# 0

# %%
tekst = 'inne zdanie na powitanie'
print(tekst.upper())
# Out:
# INNE ZDANIE NA POWITANIE

# %%
print(tekst.lower())
# Out:
# inne zdanie na powitanie

# %%
nowy_tekst = tekst.replace('powitanie', 'pożegnanie')
print(nowy_tekst)
# Out:
# inne zdanie na pożegnanie

# %%
slowa = tekst.split(' ')
print(slowa)
# Out:
# ['inne', 'zdanie', 'na', 'powitanie']

# %%
slowa = tekst.split()
print(slowa)
# Out:
# ['inne', 'zdanie', 'na', 'powitanie']

# %%
a = 80
b = 34
print(a % b)
# Out:
# 12

# %%
print(a // b)
# Out:
# 2

# %%
print(a <= b)
# Out:
# False

# %%
print(a > b)
# Out:
# True

# %%
print(a != b)
# Out:
# True

# %%
a = 38
a += 3
print(a)
# Out:
# 41

# %%
a %= 3
print(a)
# Out:
# 2

# %%
a **=2
print(a)
# Out:
# 4

# %%
a = ["PN", "WT", "ŚR", "CZ", "PT", "S", "N"]
a
# Out:
# ['PN', 'WT', 'ŚR', 'CZ', 'PT', 'S', 'N']

# %%
b = "cdefgahc"
b
# Out:
# 'cdefgahc'

# %%
a[1]
# Out:
# 'WT'

# %%
b[7]
# Out:
# 'c'

# %%
a[-1:]
# Out:
# ['N']

# %%
b[3:-1]
# Out:
# 'fgah'

# %%
q = {"a": 3, "b": -8, "simba": "99"}

# %%
print(q["a"])
# Out:
# 3

# %%
a = (q["a"])
a
# Out:
# 3

# %%
q
# Out:
# {'a': 3, 'b': -8, 'simba': '99'}

# %%
b
# Out:
# 'cdefgahc'

# %%
b = (q['b'])
b
# Out:
# -8

# %%
wiadomosc = f"Zadzwoń do {q['b']}"
wiadomosc
# Out:
# 'Zadzwoń do -8'

# %%
q['city'] = 'New York'
q
# Out:
# {'a': 3, 'b': -8, 'simba': '99', 'city': 'New York'}
