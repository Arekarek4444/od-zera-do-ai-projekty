# %%
# my_module.py
def greet(name):
    return f"Hello, {name}!"

# %%
import my_module

message = my_module.greet("Arek")
print(message)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 import my_module
#       3 message = my_module.greet("Arek")
#       4 print(message)
#
# ModuleNotFoundError: No module named 'my_module'

# %%
message = my_module.greet("Arek")
print(message)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 message = my_module.greet("Arek")
#       2 print(message)
#
# NameError: name 'my_module' is not defined
