# %%
def calculate_area(lenght, width):
    area = lenght * width
    return area
print(calculate_area(2,4))
# Out:
# 8

# %%
marka = 'Audi'
model = 'Q3 Sportback'
cena = 125000
print('marka:', marka, '/', 'model:', model, '/', 'cena:', cena)
print(marka, model,':', cena)
# Out:
# marka: Audi / model: Q3 Sportback / cena: 125000
# Audi Q3 Sportback : 125000

# %%
nowe_zdanie = f"{marka, model} kosztuje {cena}"
print(nowe_zdanie)
# Out:
# ('Audi', 'Q3 Sportback') kosztuje 125000

# %%
def calculate_sum(a, b):
    sum = a + b
    return sum
print(calculate_sum(4, 3))
# Out:
# 7

# %%
pada = False
nie_pada = True

print(pada)
print(nie_pada)
# Out:
# False
# True

# %%
pada = True
if pada:
    print('weź parasol')
else:
    print('jest ładnie, nie bierz parasola')
# Out:
# jest ładnie, nie bierz parasola

# %%
jutro_mam_wolne = True
jutro_pracuje_w_domu = True

odpoczne = not jutro_mam_wolne and jutro_pracuje_w_domu
print(odpoczne)
# Out:
# False
