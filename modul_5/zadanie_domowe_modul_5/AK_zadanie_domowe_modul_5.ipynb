# %% [markdown]
# # Zadanie domowe - łączenie danych!
#
# Wykonujesz zlecenia dla firmy, która chce żebyśmy połączyli dane z trzech różnych źródeł.
#
# 1. Pierwsze źródło danych to dane o klientach. Na szczęście zespół, który zajmuje się klientami, wie co robi i wszystkie dane dostępne są w bazie danych (`zad_domowe__clients.db` w tabeli `clients`).
# 2. Drugie źródło danych to dane o produktach. W tym przypadku dane dostępne są w pliku CSV (`zad_domowe__products.csv`).
# 3. Ostatnie źródło danych to dane o zamówieniach / fakturach. Tutaj niestety mamy problem. Okazuje się, że klient wszystkie faktury ma w postaci zrzutów z ekranu (pliki `zad_domowe__invoice_1.png`, `zad_domowe__invoice_2.png` etc.).
#
# Twoim zadaniem jest połączenie tych danych w jeden plik CSV, który będzie zawierał informacje o kliencie, produkcie i fakturze. Przygotuj plik CSV, który zawiera tylko niezbędne kolumny, nie ma żadnych kolumn powtórzonych.
#
# Jak rezultat wyciągania danych z faktur chcemy mieć w każdym wierszu informacje o zakupionym produkcie, ilości, kliencie, cenie jednostkowej.
#
# Początek kodu znajdziesz w tym notebooku.

# %%
# RESTARTUJ KERNEL PO URUCHOMIENIU
# !pip install --quiet instructor pydantic openai

# %%
from pathlib import Path
import pandas as pd
import sqlite3
import base64
from getpass import getpass
from datetime import date
import instructor
from pydantic import BaseModel
from openai import OpenAI

# %%
# będziemy potrzebować klucza API do OpenAI żeby odczytać dane z faktur
openai_key = getpass("OpenAI key: ")
# Out:
# OpenAI key:  ········

# %% [markdown]
# ## Czytamy dane klientów

# %%
with sqlite3.connect('data_zd/raw_zd/zad_domowe__clients.db') as conn:
    clients_df = pd.read_sql_query('SELECT * FROM clients', conn)

clients_df
# Out:
#      id              name                          email  \
# 0     1      Carla Ramsey           frypeter@example.net
# 1     2      Howard Mcgee     jacobpatterson@example.org
# 2     3        Eric Moore            lejacob@example.org
# 3     4       Laura Beard      westdominique@example.org
# 4     5   Joshua Santiago       sheilamedina@example.com
# ..  ...               ...                            ...
# 95   96    Heather Ortega            xmartin@example.org
# 96   97     Olivia Barnes           dpacheco@example.net
# 97   98      Tara Cabrera        geraldjames@example.net
# 98   99  Alexandra Parker  katherineharrison@example.com
# 99  100   Johnny Franklin          bankslisa@example.org
#
#                     phone
# 0     (508)998-5166x12326
# 1    001-669-353-6118x978
# 2            923-681-4646
# 3           (291)558-0966
# 4   +1-929-417-0571x74051
# ..                    ...
# 95  +1-355-627-6736x91833
# 96             9317151015
# 97        +1-984-996-5056
# 98       001-823-577-8901
# 99    (626)681-2730x71696
#
# [100 rows x 4 columns]

# %%
clients_df.sample(10)
# Out:
#     id                name                      email                phone
# 5    6        John Parsons         mhouse@example.com  +1-775-381-9658x664
# 40  41       Ryan Humphrey        derek13@example.net        (931)240-8149
# 8    9     Alexander Smith        debra94@example.org         919.678.4577
# 21  22       Gregory Perry  michellejones@example.com     995-610-5186x033
# 9   10       Antonio Jones    ryangoodman@example.org   846-767-9939x22814
# 23  24  Elizabeth Callahan      derrick78@example.org    214.778.8425x1222
# 84  85       Joshua Wilson      cgonzalez@example.org   643-519-7048x80995
# 70  71      Denise Mahoney    smithamanda@example.org     915-553-8585x373
# 92  93     Jessica Wheeler    suttonnancy@example.org    816.477.6232x6407
# 28  29      Victoria Baker          amy77@example.com  +1-202-589-9429x541

# %%
clients_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   id      100 non-null    int64
#  1   name    100 non-null    object
#  2   email   100 non-null    object
#  3   phone   100 non-null    object
# dtypes: int64(1), object(3)
# memory usage: 3.3+ KB

# %%
clients_df.nunique()
# Out:
# id       100
# name     100
# email    100
# phone    100
# dtype: int64

# %%
clients_df.isnull().sum()
# Out:
# id       0
# name     0
# email    0
# phone    0
# dtype: int64

# %%
clients_df = clients_df.rename(columns={'id': 'customer_id', 'name': 'customer_name'})
clients_df
# Out:
#     customer_id     customer_name                          email  \
# 0             1      Carla Ramsey           frypeter@example.net
# 1             2      Howard Mcgee     jacobpatterson@example.org
# 2             3        Eric Moore            lejacob@example.org
# 3             4       Laura Beard      westdominique@example.org
# 4             5   Joshua Santiago       sheilamedina@example.com
# ..          ...               ...                            ...
# 95           96    Heather Ortega            xmartin@example.org
# 96           97     Olivia Barnes           dpacheco@example.net
# 97           98      Tara Cabrera        geraldjames@example.net
# 98           99  Alexandra Parker  katherineharrison@example.com
# 99          100   Johnny Franklin          bankslisa@example.org
#
#                     phone
# 0     (508)998-5166x12326
# 1    001-669-353-6118x978
# 2            923-681-4646
# 3           (291)558-0966
# 4   +1-929-417-0571x74051
# ..                    ...
# 95  +1-355-627-6736x91833
# 96             9317151015
# 97        +1-984-996-5056
# 98       001-823-577-8901
# 99    (626)681-2730x71696
#
# [100 rows x 4 columns]

# %% [markdown]
# ## Czytamy dane produktów

# %%
products_df = pd.read_csv('data_zd/raw_zd/zad_domowe__products.csv', sep=';')
products_df
# Out:
#     id         name  price
# 0    1    telewizor     85
# 1    2       laptop     47
# 2    3     smartfon     60
# 3    4       tablet     40
# 4    5    słuchawki     40
# 5    6       kamera     92
# 6    7       router     48
# 7    8       myszka     30
# 8    9   klawiatura     65
# 9   10     pendrive     47
# 10  11        rower     69
# 11  12    hulajnoga     44
# 12  13   skateboard     81
# 13  14        rolki     11
# 14  15         kask     46
# 15  16  ochraniacze     46
# 16  17        narty     55
# 17  18    snowboard     85
# 18  19       kurtka     12
# 19  20      spodnie     14

# %%
products_df.sample(10)
# Out:
#     id         name  price
# 6    7       router     48
# 17  18    snowboard     85
# 15  16  ochraniacze     46
# 2    3     smartfon     60
# 10  11        rower     69
# 16  17        narty     55
# 11  12    hulajnoga     44
# 0    1    telewizor     85
# 18  19       kurtka     12
# 7    8       myszka     30

# %%
products_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   id      20 non-null     int64
#  1   name    20 non-null     object
#  2   price   20 non-null     int64
# dtypes: int64(2), object(1)
# memory usage: 612.0+ bytes

# %%
products_df.nunique()
# Out:
# id       20
# name     20
# price    16
# dtype: int64

# %%
products_df.isnull().sum()
# Out:
# id       0
# name     0
# price    0
# dtype: int64

# %%
products_df = products_df.rename(columns={'id': 'product_id', 'name': 'product_name'})
products_df
# Out:
#     product_id product_name  price
# 0            1    telewizor     85
# 1            2       laptop     47
# 2            3     smartfon     60
# 3            4       tablet     40
# 4            5    słuchawki     40
# 5            6       kamera     92
# 6            7       router     48
# 7            8       myszka     30
# 8            9   klawiatura     65
# 9           10     pendrive     47
# 10          11        rower     69
# 11          12    hulajnoga     44
# 12          13   skateboard     81
# 13          14        rolki     11
# 14          15         kask     46
# 15          16  ochraniacze     46
# 16          17        narty     55
# 17          18    snowboard     85
# 18          19       kurtka     12
# 19          20      spodnie     14

# %% [markdown]
# ## Czytamy dane faktur

# %%
DATA_PATH = Path('data_zd')
RAW_DATA_PATH = Path('data_zd') / 'raw_zd'
PROCESSED_DATA_PATH = Path('data_zd') / 'processed_zd'

# %%
# na szczęście mamy już strukturę którą chcemy pobrać z faktur
class InvoiceInfoItem(BaseModel):
    product_name: str
    product_id: int
    quantity: int
    price: float


class InvoiceInfo(BaseModel):
    company_name: str
    customer_id: int
    customer_name: str
    invoice_number: int
    date: date
    # mamy tutaj do czynienia z listą elementów, więc danymi zagnieżdżonymi!
    items: list[InvoiceInfoItem]


instructor_openai_client = instructor.from_openai(OpenAI(api_key=openai_key))
orders = []

# %%
def prepare_image_for_open_ai(image_path):
    with open(image_path, "rb") as f:
        image_data = base64.b64encode(f.read()).decode('utf-8')
        return f"data:image/png;base64,{image_data}"

# %%
for image_path in sorted(RAW_DATA_PATH.glob("zad_domowe__invoice_*.png")):
    print(f"Processing {image_path}")
    with open(image_path, "rb") as f:
        image_data = base64.b64encode(f.read()).decode('utf-8')

    invoice_info = instructor_openai_client.chat.completions.create(
        model="gpt-4o",
        response_model=InvoiceInfo,
        messages=[
            {
                "role": "user",
                "content": [
                    {
                        "type": "text",
                        "text": "Pobierz szczegóły faktur",
                    },
                    {
                        "type": "image_url",
                        "image_url": {
                            "url": prepare_image_for_open_ai(image_path),
                            "detail": "high"
                        },
                    },
                ],
            },
        ],
    )
    with open(PROCESSED_DATA_PATH / f"{image_path.stem}.json", "w") as f:
        f.write(invoice_info.model_dump_json())

    invoice_data = invoice_info.model_dump()
    for item in invoice_data["items"]:
        order = {
            "company_name": invoice_data["company_name"],
            "customer_id": invoice_data["customer_id"],
            "customer_name": invoice_data["customer_name"],
            "invoice_number": invoice_data["invoice_number"],
            "date": invoice_data["date"],
            "product_name": item["product_name"],
            "product_id": item["product_id"],
            "quantity": item["quantity"],
            "price": item["price"],
        }
        orders.append(order)

orders_df = pd.DataFrame(orders)
# Out:
# Processing data_zd/raw_zd/zad_domowe__invoice_1.png
# Processing data_zd/raw_zd/zad_domowe__invoice_10.png
# Processing data_zd/raw_zd/zad_domowe__invoice_2.png
# Processing data_zd/raw_zd/zad_domowe__invoice_3.png
# Processing data_zd/raw_zd/zad_domowe__invoice_4.png
# Processing data_zd/raw_zd/zad_domowe__invoice_5.png
# Processing data_zd/raw_zd/zad_domowe__invoice_6.png
# Processing data_zd/raw_zd/zad_domowe__invoice_7.png
# Processing data_zd/raw_zd/zad_domowe__invoice_8.png
# Processing data_zd/raw_zd/zad_domowe__invoice_9.png

# %%
orders_df
# Out:
#    company_name  customer_id      customer_name  invoice_number       date  \
# 0     Firma XYZ            3         Eric Moore               2 2024-05-25
# 1     Firma XYZ            3         Eric Moore               2 2024-05-25
# 2     Firma XYZ           92    Valerie Stevens              11 2024-05-02
# 3     Firma XYZ           60     Troy Alexander               3 2024-05-19
# 4     Firma XYZ           78  William Velazquez               4 2024-03-26
# 5     Firma XYZ           33     Steven Jackson               5 2024-07-23
# 6     Firma XYZ           33     Steven Jackson               5 2024-07-23
# 7     Firma XYZ            8    Ronald Callahan               6 2024-03-14
# 8     Firma XYZ            8    Ronald Callahan               6 2024-03-14
# 9     Firma XYZ            4        Laura Beard               7 2024-06-24
# 10    Firma XYZ           63     Alexis Johnson               8 2024-02-21
# 11    Firma XYZ           63     Alexis Johnson               8 2024-02-21
# 12    Firma XYZ           63     Alexis Johnson               8 2024-02-21
# 13    Firma XYZ          100    Johnny Franklin               9 2024-01-26
# 14    Firma XYZ           44   Kimberly Marquez              10 2024-03-14
# 15    Firma XYZ           44   Kimberly Marquez              10 2024-03-14
#
#    product_name  product_id  quantity  price
# 0        router           7         3   48.0
# 1         narty          17         5   55.0
# 2     słuchawki           5         1   40.0
# 3   ochraniacze          16         4   46.0
# 4         rolki          14         3   11.0
# 5      pendrive          10         4   47.0
# 6        laptop           2         2   47.0
# 7     słuchawki           5         4   40.0
# 8   ochraniacze          16         2   46.0
# 9     telewizor           1         2   85.0
# 10   klawiatura           9         1   65.0
# 11       router           7         1   48.0
# 12      spodnie          20         1   14.0
# 13      spodnie          20         2   14.0
# 14       laptop           2         1   47.0
# 15   klawiatura           9         2   65.0

# %%
orders_df.sample(10)
# Out:
#    company_name  customer_id     customer_name  invoice_number        date  \
# 5     Firma XYZ           33    Steven Jackson               5  2024-07-23
# 12    Firma XYZ           63    Alexis Johnson               8  2024-02-21
# 2     Firma XYZ           92   Valerie Stevens              11  2024-05-02
# 8     Firma XYZ            8   Ronald Callahan               6  2024-03-14
# 11    Firma XYZ           63    Alexis Johnson               8  2024-02-21
# 7     Firma XYZ            8   Ronald Callahan               6  2024-03-14
# 15    Firma XYZ           44  Kimberly Marquez              10  2024-03-14
# 9     Firma XYZ            4       Laura Beard               7  2024-06-24
# 13    Firma XYZ          100   Johnny Franklin               9  2024-01-26
# 1     Firma XYZ            3        Eric Moore               2  2024-05-25
#
#    product_name  product_id  quantity  price
# 5      pendrive          10         4   47.0
# 12      spodnie          20         1   14.0
# 2     słuchawki           5         1   40.0
# 8   ochraniacze          16         2   46.0
# 11       router           7         1   48.0
# 7     słuchawki           5         4   40.0
# 15   klawiatura           9         2   65.0
# 9     telewizor           1         2   85.0
# 13      spodnie          20         2   14.0
# 1         narty          17         5   55.0

# %%
orders_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16 entries, 0 to 15
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   company_name    16 non-null     object
#  1   customer_id     16 non-null     int64
#  2   customer_name   16 non-null     object
#  3   invoice_number  16 non-null     int64
#  4   date            16 non-null     object
#  5   product_name    16 non-null     object
#  6   product_id      16 non-null     int64
#  7   quantity        16 non-null     int64
#  8   price           16 non-null     float64
# dtypes: float64(1), int64(4), object(4)
# memory usage: 1.3+ KB

# %%
orders_df.nunique()
# Out:
# company_name       1
# customer_id       10
# customer_name     10
# invoice_number    10
# date               9
# product_name      10
# product_id        10
# quantity           5
# price              9
# dtype: int64

# %%
orders_df['date'] = pd.to_datetime(orders_df['date'])
orders_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16 entries, 0 to 15
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   company_name    16 non-null     object
#  1   customer_id     16 non-null     int64
#  2   customer_name   16 non-null     object
#  3   invoice_number  16 non-null     int64
#  4   date            16 non-null     datetime64[ns]
#  5   product_name    16 non-null     object
#  6   product_id      16 non-null     int64
#  7   quantity        16 non-null     int64
#  8   price           16 non-null     float64
# dtypes: datetime64[ns](1), float64(1), int64(4), object(3)
# memory usage: 1.3+ KB

# %%
orders_df.isnull().sum()
# Out:
# company_name      0
# customer_id       0
# customer_name     0
# invoice_number    0
# date              0
# product_name      0
# product_id        0
# quantity          0
# price             0
# dtype: int64

# %% [markdown]
# ## Łączenie danych

# %%
orders_products_df = orders_df.merge(products_df, on='product_id', how='outer')
orders_products_df
# Out:
#    company_name  customer_id      customer_name  invoice_number       date  \
# 0     Firma XYZ          3.0         Eric Moore             2.0 2024-05-25
# 1     Firma XYZ         63.0     Alexis Johnson             8.0 2024-02-21
# 2     Firma XYZ          3.0         Eric Moore             2.0 2024-05-25
# 3     Firma XYZ         92.0    Valerie Stevens            11.0 2024-05-02
# 4     Firma XYZ          8.0    Ronald Callahan             6.0 2024-03-14
# 5     Firma XYZ         60.0     Troy Alexander             3.0 2024-05-19
# 6     Firma XYZ          8.0    Ronald Callahan             6.0 2024-03-14
# 7     Firma XYZ         78.0  William Velazquez             4.0 2024-03-26
# 8     Firma XYZ         33.0     Steven Jackson             5.0 2024-07-23
# 9     Firma XYZ         33.0     Steven Jackson             5.0 2024-07-23
# 10    Firma XYZ         44.0   Kimberly Marquez            10.0 2024-03-14
# 11    Firma XYZ          4.0        Laura Beard             7.0 2024-06-24
# 12    Firma XYZ         63.0     Alexis Johnson             8.0 2024-02-21
# 13    Firma XYZ         44.0   Kimberly Marquez            10.0 2024-03-14
# 14    Firma XYZ         63.0     Alexis Johnson             8.0 2024-02-21
# 15    Firma XYZ        100.0    Johnny Franklin             9.0 2024-01-26
# 16          NaN          NaN                NaN             NaN        NaT
# 17          NaN          NaN                NaN             NaN        NaT
# 18          NaN          NaN                NaN             NaN        NaT
# 19          NaN          NaN                NaN             NaN        NaT
# 20          NaN          NaN                NaN             NaN        NaT
# 21          NaN          NaN                NaN             NaN        NaT
# 22          NaN          NaN                NaN             NaN        NaT
# 23          NaN          NaN                NaN             NaN        NaT
# 24          NaN          NaN                NaN             NaN        NaT
# 25          NaN          NaN                NaN             NaN        NaT
#
#    product_name_x  product_id  quantity  price_x product_name_y  price_y
# 0          router           7       3.0     48.0         router       48
# 1          router           7       1.0     48.0         router       48
# 2           narty          17       5.0     55.0          narty       55
# 3       słuchawki           5       1.0     40.0      słuchawki       40
# 4       słuchawki           5       4.0     40.0      słuchawki       40
# 5     ochraniacze          16       4.0     46.0    ochraniacze       46
# 6     ochraniacze          16       2.0     46.0    ochraniacze       46
# 7           rolki          14       3.0     11.0          rolki       11
# 8        pendrive          10       4.0     47.0       pendrive       47
# 9          laptop           2       2.0     47.0         laptop       47
# 10         laptop           2       1.0     47.0         laptop       47
# 11      telewizor           1       2.0     85.0      telewizor       85
# 12     klawiatura           9       1.0     65.0     klawiatura       65
# 13     klawiatura           9       2.0     65.0     klawiatura       65
# 14        spodnie          20       1.0     14.0        spodnie       14
# 15        spodnie          20       2.0     14.0        spodnie       14
# 16            NaN           3       NaN      NaN       smartfon       60
# 17            NaN           4       NaN      NaN         tablet       40
# 18            NaN           6       NaN      NaN         kamera       92
# 19            NaN           8       NaN      NaN         myszka       30
# 20            NaN          11       NaN      NaN          rower       69
# 21            NaN          12       NaN      NaN      hulajnoga       44
# 22            NaN          13       NaN      NaN     skateboard       81
# 23            NaN          15       NaN      NaN           kask       46
# 24            NaN          18       NaN      NaN      snowboard       85
# 25            NaN          19       NaN      NaN         kurtka       12

# %%
orders_products_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 26 entries, 0 to 25
# Data columns (total 11 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   company_name    16 non-null     object
#  1   customer_id     16 non-null     float64
#  2   customer_name   16 non-null     object
#  3   invoice_number  16 non-null     float64
#  4   date            16 non-null     datetime64[ns]
#  5   product_name_x  16 non-null     object
#  6   product_id      26 non-null     int64
#  7   quantity        16 non-null     float64
#  8   price_x         16 non-null     float64
#  9   product_name_y  26 non-null     object
#  10  price_y         26 non-null     int64
# dtypes: datetime64[ns](1), float64(4), int64(2), object(4)
# memory usage: 2.4+ KB

# %%
orders_products_df = orders_products_df.drop('product_name_x', axis=1)

# %%
orders_products_df = orders_products_df.drop('price_x', axis=1)

# %%
orders_products_df = orders_products_df.rename(columns={'product_name_y': 'product_name', 'price_y': 'price'})

# %%
orders_products_df.nunique()
# Out:
# company_name       1
# customer_id       10
# customer_name     10
# invoice_number    10
# date               9
# product_id        20
# quantity           5
# product_name      20
# price             16
# dtype: int64

# %%
orders_products_df.isnull().sum()
# Out:
# company_name      10
# customer_id       10
# customer_name     10
# invoice_number    10
# date              10
# product_id         0
# quantity          10
# product_name       0
# price              0
# dtype: int64

# %%
orders_products_df = orders_products_df.fillna({
    'company_name': 'NO SALES',
    'customer_id': 0,
    'customer_name': 'NO SALES',
    'invoice_number': 0,
    'quantity': 0})
orders_products_df
# Out:
#    company_name  customer_id      customer_name  invoice_number       date  \
# 0     Firma XYZ          3.0         Eric Moore             2.0 2024-05-25
# 1     Firma XYZ         63.0     Alexis Johnson             8.0 2024-02-21
# 2     Firma XYZ          3.0         Eric Moore             2.0 2024-05-25
# 3     Firma XYZ         92.0    Valerie Stevens            11.0 2024-05-02
# 4     Firma XYZ          8.0    Ronald Callahan             6.0 2024-03-14
# 5     Firma XYZ         60.0     Troy Alexander             3.0 2024-05-19
# 6     Firma XYZ          8.0    Ronald Callahan             6.0 2024-03-14
# 7     Firma XYZ         78.0  William Velazquez             4.0 2024-03-26
# 8     Firma XYZ         33.0     Steven Jackson             5.0 2024-07-23
# 9     Firma XYZ         33.0     Steven Jackson             5.0 2024-07-23
# 10    Firma XYZ         44.0   Kimberly Marquez            10.0 2024-03-14
# 11    Firma XYZ          4.0        Laura Beard             7.0 2024-06-24
# 12    Firma XYZ         63.0     Alexis Johnson             8.0 2024-02-21
# 13    Firma XYZ         44.0   Kimberly Marquez            10.0 2024-03-14
# 14    Firma XYZ         63.0     Alexis Johnson             8.0 2024-02-21
# 15    Firma XYZ        100.0    Johnny Franklin             9.0 2024-01-26
# 16     NO SALES          0.0           NO SALES             0.0        NaT
# 17     NO SALES          0.0           NO SALES             0.0        NaT
# 18     NO SALES          0.0           NO SALES             0.0        NaT
# 19     NO SALES          0.0           NO SALES             0.0        NaT
# 20     NO SALES          0.0           NO SALES             0.0        NaT
# 21     NO SALES          0.0           NO SALES             0.0        NaT
# 22     NO SALES          0.0           NO SALES             0.0        NaT
# 23     NO SALES          0.0           NO SALES             0.0        NaT
# 24     NO SALES          0.0           NO SALES             0.0        NaT
# 25     NO SALES          0.0           NO SALES             0.0        NaT
#
#     product_id  quantity product_name  price
# 0            7       3.0       router     48
# 1            7       1.0       router     48
# 2           17       5.0        narty     55
# 3            5       1.0    słuchawki     40
# 4            5       4.0    słuchawki     40
# 5           16       4.0  ochraniacze     46
# 6           16       2.0  ochraniacze     46
# 7           14       3.0        rolki     11
# 8           10       4.0     pendrive     47
# 9            2       2.0       laptop     47
# 10           2       1.0       laptop     47
# 11           1       2.0    telewizor     85
# 12           9       1.0   klawiatura     65
# 13           9       2.0   klawiatura     65
# 14          20       1.0      spodnie     14
# 15          20       2.0      spodnie     14
# 16           3       0.0     smartfon     60
# 17           4       0.0       tablet     40
# 18           6       0.0       kamera     92
# 19           8       0.0       myszka     30
# 20          11       0.0        rower     69
# 21          12       0.0    hulajnoga     44
# 22          13       0.0   skateboard     81
# 23          15       0.0         kask     46
# 24          18       0.0    snowboard     85
# 25          19       0.0       kurtka     12

# %%
company_df = pd.merge(orders_products_df, clients_df, on='customer_id', how='left')
company_df
# Out:
#    company_name  customer_id    customer_name_x  invoice_number       date  \
# 0     Firma XYZ          3.0         Eric Moore             2.0 2024-05-25
# 1     Firma XYZ         63.0     Alexis Johnson             8.0 2024-02-21
# 2     Firma XYZ          3.0         Eric Moore             2.0 2024-05-25
# 3     Firma XYZ         92.0    Valerie Stevens            11.0 2024-05-02
# 4     Firma XYZ          8.0    Ronald Callahan             6.0 2024-03-14
# 5     Firma XYZ         60.0     Troy Alexander             3.0 2024-05-19
# 6     Firma XYZ          8.0    Ronald Callahan             6.0 2024-03-14
# 7     Firma XYZ         78.0  William Velazquez             4.0 2024-03-26
# 8     Firma XYZ         33.0     Steven Jackson             5.0 2024-07-23
# 9     Firma XYZ         33.0     Steven Jackson             5.0 2024-07-23
# 10    Firma XYZ         44.0   Kimberly Marquez            10.0 2024-03-14
# 11    Firma XYZ          4.0        Laura Beard             7.0 2024-06-24
# 12    Firma XYZ         63.0     Alexis Johnson             8.0 2024-02-21
# 13    Firma XYZ         44.0   Kimberly Marquez            10.0 2024-03-14
# 14    Firma XYZ         63.0     Alexis Johnson             8.0 2024-02-21
# 15    Firma XYZ        100.0    Johnny Franklin             9.0 2024-01-26
# 16     NO SALES          0.0           NO SALES             0.0        NaT
# 17     NO SALES          0.0           NO SALES             0.0        NaT
# 18     NO SALES          0.0           NO SALES             0.0        NaT
# 19     NO SALES          0.0           NO SALES             0.0        NaT
# 20     NO SALES          0.0           NO SALES             0.0        NaT
# 21     NO SALES          0.0           NO SALES             0.0        NaT
# 22     NO SALES          0.0           NO SALES             0.0        NaT
# 23     NO SALES          0.0           NO SALES             0.0        NaT
# 24     NO SALES          0.0           NO SALES             0.0        NaT
# 25     NO SALES          0.0           NO SALES             0.0        NaT
#
#     product_id  quantity product_name  price    customer_name_y  \
# 0            7       3.0       router     48         Eric Moore
# 1            7       1.0       router     48     Alexis Johnson
# 2           17       5.0        narty     55         Eric Moore
# 3            5       1.0    słuchawki     40    Valerie Stevens
# 4            5       4.0    słuchawki     40    Ronald Callahan
# 5           16       4.0  ochraniacze     46     Troy Alexander
# 6           16       2.0  ochraniacze     46    Ronald Callahan
# 7           14       3.0        rolki     11  William Velazquez
# 8           10       4.0     pendrive     47     Steven Jackson
# 9            2       2.0       laptop     47     Steven Jackson
# 10           2       1.0       laptop     47   Kimberly Marquez
# 11           1       2.0    telewizor     85        Laura Beard
# 12           9       1.0   klawiatura     65     Alexis Johnson
# 13           9       2.0   klawiatura     65   Kimberly Marquez
# 14          20       1.0      spodnie     14     Alexis Johnson
# 15          20       2.0      spodnie     14    Johnny Franklin
# 16           3       0.0     smartfon     60                NaN
# 17           4       0.0       tablet     40                NaN
# 18           6       0.0       kamera     92                NaN
# 19           8       0.0       myszka     30                NaN
# 20          11       0.0        rower     69                NaN
# 21          12       0.0    hulajnoga     44                NaN
# 22          13       0.0   skateboard     81                NaN
# 23          15       0.0         kask     46                NaN
# 24          18       0.0    snowboard     85                NaN
# 25          19       0.0       kurtka     12                NaN
#
#                           email                 phone
# 0           lejacob@example.org          923-681-4646
# 1   campbellkatrina@example.org         (311)679-3346
# 2           lejacob@example.org          923-681-4646
# 3             xlowe@example.com    757-943-1579x98346
# 4          audrey56@example.com   +1-727-668-2720x085
# 5           nturner@example.net   +1-212-349-3992x430
# 6          audrey56@example.com   +1-727-668-2720x085
# 7            lisa25@example.net     (765)602-1572x949
# 8          jeremy07@example.com          481.258.2434
# 9          jeremy07@example.com          481.258.2434
# 10         joseph28@example.net  +1-688-249-5941x6260
# 11    westdominique@example.org         (291)558-0966
# 12  campbellkatrina@example.org         (311)679-3346
# 13         joseph28@example.net  +1-688-249-5941x6260
# 14  campbellkatrina@example.org         (311)679-3346
# 15        bankslisa@example.org   (626)681-2730x71696
# 16                          NaN                   NaN
# 17                          NaN                   NaN
# 18                          NaN                   NaN
# 19                          NaN                   NaN
# 20                          NaN                   NaN
# 21                          NaN                   NaN
# 22                          NaN                   NaN
# 23                          NaN                   NaN
# 24                          NaN                   NaN
# 25                          NaN                   NaN

# %%
company_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 26 entries, 0 to 25
# Data columns (total 12 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   company_name     26 non-null     object
#  1   customer_id      26 non-null     float64
#  2   customer_name_x  26 non-null     object
#  3   invoice_number   26 non-null     float64
#  4   date             16 non-null     datetime64[ns]
#  5   product_id       26 non-null     int64
#  6   quantity         26 non-null     float64
#  7   product_name     26 non-null     object
#  8   price            26 non-null     int64
#  9   customer_name_y  16 non-null     object
#  10  email            16 non-null     object
#  11  phone            16 non-null     object
# dtypes: datetime64[ns](1), float64(3), int64(2), object(6)
# memory usage: 2.6+ KB

# %%
company_df = company_df.drop('customer_name_y', axis=1)
company_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 26 entries, 0 to 25
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   company_name     26 non-null     object
#  1   customer_id      26 non-null     float64
#  2   customer_name_x  26 non-null     object
#  3   invoice_number   26 non-null     float64
#  4   date             16 non-null     datetime64[ns]
#  5   product_id       26 non-null     int64
#  6   quantity         26 non-null     float64
#  7   product_name     26 non-null     object
#  8   price            26 non-null     int64
#  9   email            16 non-null     object
#  10  phone            16 non-null     object
# dtypes: datetime64[ns](1), float64(3), int64(2), object(5)
# memory usage: 2.4+ KB

# %%
company_df = company_df.rename(columns={'customer_name_x': 'customer_name'})
company_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 26 entries, 0 to 25
# Data columns (total 11 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   company_name    26 non-null     object
#  1   customer_id     26 non-null     float64
#  2   customer_name   26 non-null     object
#  3   invoice_number  26 non-null     float64
#  4   date            16 non-null     datetime64[ns]
#  5   product_id      26 non-null     int64
#  6   quantity        26 non-null     float64
#  7   product_name    26 non-null     object
#  8   price           26 non-null     int64
#  9   email           16 non-null     object
#  10  phone           16 non-null     object
# dtypes: datetime64[ns](1), float64(3), int64(2), object(5)
# memory usage: 2.4+ KB

# %%
company_df.isnull().sum()
# Out:
# company_name       0
# customer_id        0
# customer_name      0
# invoice_number     0
# date              10
# product_id         0
# quantity           0
# product_name       0
# price              0
# email             10
# phone             10
# dtype: int64

# %%
company_df = company_df.fillna({
    'email': 'NO SALES',
    'phone': 'NO SALES' })
company_df
# Out:
#    company_name  customer_id      customer_name  invoice_number       date  \
# 0     Firma XYZ          3.0         Eric Moore             2.0 2024-05-25
# 1     Firma XYZ         63.0     Alexis Johnson             8.0 2024-02-21
# 2     Firma XYZ          3.0         Eric Moore             2.0 2024-05-25
# 3     Firma XYZ         92.0    Valerie Stevens            11.0 2024-05-02
# 4     Firma XYZ          8.0    Ronald Callahan             6.0 2024-03-14
# 5     Firma XYZ         60.0     Troy Alexander             3.0 2024-05-19
# 6     Firma XYZ          8.0    Ronald Callahan             6.0 2024-03-14
# 7     Firma XYZ         78.0  William Velazquez             4.0 2024-03-26
# 8     Firma XYZ         33.0     Steven Jackson             5.0 2024-07-23
# 9     Firma XYZ         33.0     Steven Jackson             5.0 2024-07-23
# 10    Firma XYZ         44.0   Kimberly Marquez            10.0 2024-03-14
# 11    Firma XYZ          4.0        Laura Beard             7.0 2024-06-24
# 12    Firma XYZ         63.0     Alexis Johnson             8.0 2024-02-21
# 13    Firma XYZ         44.0   Kimberly Marquez            10.0 2024-03-14
# 14    Firma XYZ         63.0     Alexis Johnson             8.0 2024-02-21
# 15    Firma XYZ        100.0    Johnny Franklin             9.0 2024-01-26
# 16     NO SALES          0.0           NO SALES             0.0        NaT
# 17     NO SALES          0.0           NO SALES             0.0        NaT
# 18     NO SALES          0.0           NO SALES             0.0        NaT
# 19     NO SALES          0.0           NO SALES             0.0        NaT
# 20     NO SALES          0.0           NO SALES             0.0        NaT
# 21     NO SALES          0.0           NO SALES             0.0        NaT
# 22     NO SALES          0.0           NO SALES             0.0        NaT
# 23     NO SALES          0.0           NO SALES             0.0        NaT
# 24     NO SALES          0.0           NO SALES             0.0        NaT
# 25     NO SALES          0.0           NO SALES             0.0        NaT
#
#     product_id  quantity product_name  price                        email  \
# 0            7       3.0       router     48          lejacob@example.org
# 1            7       1.0       router     48  campbellkatrina@example.org
# 2           17       5.0        narty     55          lejacob@example.org
# 3            5       1.0    słuchawki     40            xlowe@example.com
# 4            5       4.0    słuchawki     40         audrey56@example.com
# 5           16       4.0  ochraniacze     46          nturner@example.net
# 6           16       2.0  ochraniacze     46         audrey56@example.com
# 7           14       3.0        rolki     11           lisa25@example.net
# 8           10       4.0     pendrive     47         jeremy07@example.com
# 9            2       2.0       laptop     47         jeremy07@example.com
# 10           2       1.0       laptop     47         joseph28@example.net
# 11           1       2.0    telewizor     85    westdominique@example.org
# 12           9       1.0   klawiatura     65  campbellkatrina@example.org
# 13           9       2.0   klawiatura     65         joseph28@example.net
# 14          20       1.0      spodnie     14  campbellkatrina@example.org
# 15          20       2.0      spodnie     14        bankslisa@example.org
# 16           3       0.0     smartfon     60                     NO SALES
# 17           4       0.0       tablet     40                     NO SALES
# 18           6       0.0       kamera     92                     NO SALES
# 19           8       0.0       myszka     30                     NO SALES
# 20          11       0.0        rower     69                     NO SALES
# 21          12       0.0    hulajnoga     44                     NO SALES
# 22          13       0.0   skateboard     81                     NO SALES
# 23          15       0.0         kask     46                     NO SALES
# 24          18       0.0    snowboard     85                     NO SALES
# 25          19       0.0       kurtka     12                     NO SALES
#
#                    phone
# 0           923-681-4646
# 1          (311)679-3346
# 2           923-681-4646
# 3     757-943-1579x98346
# 4    +1-727-668-2720x085
# 5    +1-212-349-3992x430
# 6    +1-727-668-2720x085
# 7      (765)602-1572x949
# 8           481.258.2434
# 9           481.258.2434
# 10  +1-688-249-5941x6260
# 11         (291)558-0966
# 12         (311)679-3346
# 13  +1-688-249-5941x6260
# 14         (311)679-3346
# 15   (626)681-2730x71696
# 16              NO SALES
# 17              NO SALES
# 18              NO SALES
# 19              NO SALES
# 20              NO SALES
# 21              NO SALES
# 22              NO SALES
# 23              NO SALES
# 24              NO SALES
# 25              NO SALES

# %%
company_df = company_df[['date', 'product_id', 'product_name', 'quantity', 'price', 'company_name', 'customer_id', 'customer_name', 'invoice_number', 'email', 'phone']]

# %%
company_df
# Out:
#          date  product_id product_name  quantity  price company_name  \
# 0  2024-05-25           7       router       3.0     48    Firma XYZ
# 1  2024-02-21           7       router       1.0     48    Firma XYZ
# 2  2024-05-25          17        narty       5.0     55    Firma XYZ
# 3  2024-05-02           5    słuchawki       1.0     40    Firma XYZ
# 4  2024-03-14           5    słuchawki       4.0     40    Firma XYZ
# 5  2024-05-19          16  ochraniacze       4.0     46    Firma XYZ
# 6  2024-03-14          16  ochraniacze       2.0     46    Firma XYZ
# 7  2024-03-26          14        rolki       3.0     11    Firma XYZ
# 8  2024-07-23          10     pendrive       4.0     47    Firma XYZ
# 9  2024-07-23           2       laptop       2.0     47    Firma XYZ
# 10 2024-03-14           2       laptop       1.0     47    Firma XYZ
# 11 2024-06-24           1    telewizor       2.0     85    Firma XYZ
# 12 2024-02-21           9   klawiatura       1.0     65    Firma XYZ
# 13 2024-03-14           9   klawiatura       2.0     65    Firma XYZ
# 14 2024-02-21          20      spodnie       1.0     14    Firma XYZ
# 15 2024-01-26          20      spodnie       2.0     14    Firma XYZ
# 16        NaT           3     smartfon       0.0     60     NO SALES
# 17        NaT           4       tablet       0.0     40     NO SALES
# 18        NaT           6       kamera       0.0     92     NO SALES
# 19        NaT           8       myszka       0.0     30     NO SALES
# 20        NaT          11        rower       0.0     69     NO SALES
# 21        NaT          12    hulajnoga       0.0     44     NO SALES
# 22        NaT          13   skateboard       0.0     81     NO SALES
# 23        NaT          15         kask       0.0     46     NO SALES
# 24        NaT          18    snowboard       0.0     85     NO SALES
# 25        NaT          19       kurtka       0.0     12     NO SALES
#
#     customer_id      customer_name  invoice_number  \
# 0           3.0         Eric Moore             2.0
# 1          63.0     Alexis Johnson             8.0
# 2           3.0         Eric Moore             2.0
# 3          92.0    Valerie Stevens            11.0
# 4           8.0    Ronald Callahan             6.0
# 5          60.0     Troy Alexander             3.0
# 6           8.0    Ronald Callahan             6.0
# 7          78.0  William Velazquez             4.0
# 8          33.0     Steven Jackson             5.0
# 9          33.0     Steven Jackson             5.0
# 10         44.0   Kimberly Marquez            10.0
# 11          4.0        Laura Beard             7.0
# 12         63.0     Alexis Johnson             8.0
# 13         44.0   Kimberly Marquez            10.0
# 14         63.0     Alexis Johnson             8.0
# 15        100.0    Johnny Franklin             9.0
# 16          0.0           NO SALES             0.0
# 17          0.0           NO SALES             0.0
# 18          0.0           NO SALES             0.0
# 19          0.0           NO SALES             0.0
# 20          0.0           NO SALES             0.0
# 21          0.0           NO SALES             0.0
# 22          0.0           NO SALES             0.0
# 23          0.0           NO SALES             0.0
# 24          0.0           NO SALES             0.0
# 25          0.0           NO SALES             0.0
#
#                           email                 phone
# 0           lejacob@example.org          923-681-4646
# 1   campbellkatrina@example.org         (311)679-3346
# 2           lejacob@example.org          923-681-4646
# 3             xlowe@example.com    757-943-1579x98346
# 4          audrey56@example.com   +1-727-668-2720x085
# 5           nturner@example.net   +1-212-349-3992x430
# 6          audrey56@example.com   +1-727-668-2720x085
# 7            lisa25@example.net     (765)602-1572x949
# 8          jeremy07@example.com          481.258.2434
# 9          jeremy07@example.com          481.258.2434
# 10         joseph28@example.net  +1-688-249-5941x6260
# 11    westdominique@example.org         (291)558-0966
# 12  campbellkatrina@example.org         (311)679-3346
# 13         joseph28@example.net  +1-688-249-5941x6260
# 14  campbellkatrina@example.org         (311)679-3346
# 15        bankslisa@example.org   (626)681-2730x71696
# 16                     NO SALES              NO SALES
# 17                     NO SALES              NO SALES
# 18                     NO SALES              NO SALES
# 19                     NO SALES              NO SALES
# 20                     NO SALES              NO SALES
# 21                     NO SALES              NO SALES
# 22                     NO SALES              NO SALES
# 23                     NO SALES              NO SALES
# 24                     NO SALES              NO SALES
# 25                     NO SALES              NO SALES

# %% [markdown]
# company_df = company_df.sort_values(by='date')
# company_df

# %% [markdown]
# ## Transakcje są posortowane wg dat sprzedaży. Tabela obejmuje wszystkie produkty, również te niesprzedane.

# %%
company_df.to_csv('AK_zadanie_domowe_modul_5.csv', index=False)
